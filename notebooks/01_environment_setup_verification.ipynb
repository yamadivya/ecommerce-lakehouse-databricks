# %%
print(f"Spark Version: {spark.version}")
print(f"Databricks Runtime: {spark.conf.get('spark.databricks.clusterUsageTags.sparkVersion')}")

import delta
print(f"Delta Version: {delta.__version__}")
# Out:
# Spark Version: 3.5.2
# Databricks Runtime: 16.4.x-photon-scala2.12
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <command-6494452543425644>, line 5
#       2 print(f"Databricks Runtime: {spark.conf.get('spark.databricks.clusterUsageTags.sparkVersion')}")
#       4 import delta
# ----> 5 print(f"Delta Version: {delta.__version__}")
#
# AttributeError: module 'delta' has no attribute '__version__'

# %%
# Should show ecommerce catalog
spark.sql("SHOW CATALOGS").show()
# Out:
# +------------------+
# |           catalog|
# +------------------+
# |dbw_ecommerce_prod|
# |         ecommerce|
# |    hive_metastore|
# |           samples|
# |            system|
# +------------------+

# %%
# Should show bronze, silver, gold
spark.sql("SHOW SCHEMAS IN ecommerce").show()
# Out:
# +------------------+
# |      databaseName|
# +------------------+
# |            bronze|
# |           default|
# |              gold|
# |information_schema|
# |            silver|
# +------------------+

# %%
test_df = spark.createDataFrame(
    [("order_001", "Divya", 99.99)],
    ["order_id", "customer_name", "total"]
)

test_df.write.format("delta").mode("overwrite") \
    .saveAsTable("ecommerce.bronze.setup_test")

print("✅ Test table written successfully!")
# Out:
# ✅ Test table written successfully!

# %%
# Cell 5
spark.table("ecommerce.bronze.setup_test").show()
# Out:
# +---------+-------------+-----+
# | order_id|customer_name|total|
# +---------+-------------+-----+
# |order_001|        Divya|99.99|
# +---------+-------------+-----+

# %%
# Cell 6
spark.sql("DROP TABLE IF EXISTS ecommerce.bronze.setup_test")
print("Cleanup done!")
# Out:
# Cleanup done!
